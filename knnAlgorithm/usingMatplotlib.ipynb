# %%
import matplotlib.pyplot as plt
x = [459, 738, 473, 1094, 610, 806, 768, 539, 472, 666, 519, 1093, 757, 493, 830, 630]
y = [259, 435, 315, 605, 365, 488, 467, 302, 288, 410, 295, 640, 454, 319, 523, 420]
plt.plot(x, y, 'bo')

plt.show()
